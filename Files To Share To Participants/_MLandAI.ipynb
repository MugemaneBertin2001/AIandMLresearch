# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('houses.csv')

# %%
df
# Out:
#       Number   Location     Area             Price  Bedrooms  Bathrooms  \
# 0          1   Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0
# 1          2   Gacuriro      sqm  180 000 000  Rwf       4.0        4.0
# 2          3     Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0
# 3          4        NaN      sqm    8 500 000  Rwf       3.0        NaN
# 4          5  Kimironko      sqm   28 000 000  Rwf       4.0        3.0
# ...      ...        ...      ...               ...       ...        ...
# 4794    4795    Kanombe      sqm   52 000 000  Rwf       4.0        3.0
# 4795    4796        NaN  500 sqm   14 000 000  Rwf       5.0        2.0
# 4796    4797    Rugende  945 sqm   28 500 000  Rwf       5.0        3.0
# 4797    4798     Kabuga  30/20 m   15 000 000  Rwf       4.0        1.0
# 4798    4799     Kabuga      sqm   30 000 000  Rwf       3.0        2.0
#
#      Wardrobes Cabinets Balcony Parking Quarters
# 0          NaN      NaN     NaN     Yes      Yes
# 1          NaN      NaN     Yes     NaN      NaN
# 2          NaN      NaN     NaN     NaN      NaN
# 3          NaN      NaN     NaN     NaN      NaN
# 4          Yes      Yes     Yes     Yes      Yes
# ...        ...      ...     ...     ...      ...
# 4794       NaN      Yes     NaN     NaN      NaN
# 4795       NaN      NaN     Yes     NaN      Yes
# 4796       NaN      NaN     NaN     NaN      NaN
# 4797       Yes      Yes     Yes     Yes      NaN
# 4798       NaN      NaN     Yes     NaN      NaN
#
# [4799 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4799 entries, 0 to 4798
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Number      4799 non-null   int64
#  1     Location  4241 non-null   object
#  2     Area      4799 non-null   object
#  3     Price     4799 non-null   object
#  4   Bedrooms    4270 non-null   float64
#  5   Bathrooms   4510 non-null   float64
#  6   Wardrobes   1021 non-null   object
#  7   Cabinets    1466 non-null   object
#  8   Balcony     1074 non-null   object
#  9   Parking     3220 non-null   object
#  10  Quarters    2820 non-null   object
# dtypes: float64(2), int64(1), object(8)
# memory usage: 412.5+ KB

# %%
df.nunique(dropna = False)
# Out:
# Number        4799
#   Location     119
#   Area         146
#   Price        165
# Bedrooms        15
# Bathrooms       11
# Wardrobes        2
# Cabinets         2
# Balcony          2
# Parking          2
# Quarters         2
# dtype: int64

# %%
df.drop('Number', axis = 1, inplace = True)

# %%
df
# Out:
#        Location     Area             Price  Bedrooms  Bathrooms Wardrobes  \
# 0      Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0       NaN
# 1      Gacuriro      sqm  180 000 000  Rwf       4.0        4.0       NaN
# 2        Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0       NaN
# 3           NaN      sqm    8 500 000  Rwf       3.0        NaN       NaN
# 4     Kimironko      sqm   28 000 000  Rwf       4.0        3.0       Yes
# ...         ...      ...               ...       ...        ...       ...
# 4794    Kanombe      sqm   52 000 000  Rwf       4.0        3.0       NaN
# 4795        NaN  500 sqm   14 000 000  Rwf       5.0        2.0       NaN
# 4796    Rugende  945 sqm   28 500 000  Rwf       5.0        3.0       NaN
# 4797     Kabuga  30/20 m   15 000 000  Rwf       4.0        1.0       Yes
# 4798     Kabuga      sqm   30 000 000  Rwf       3.0        2.0       NaN
#
#      Cabinets Balcony Parking Quarters
# 0         NaN     NaN     Yes      Yes
# 1         NaN     Yes     NaN      NaN
# 2         NaN     NaN     NaN      NaN
# 3         NaN     NaN     NaN      NaN
# 4         Yes     Yes     Yes      Yes
# ...       ...     ...     ...      ...
# 4794      Yes     NaN     NaN      NaN
# 4795      NaN     Yes     NaN      Yes
# 4796      NaN     NaN     NaN      NaN
# 4797      Yes     Yes     Yes      NaN
# 4798      NaN     Yes     NaN      NaN
#
# [4799 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
#   Location     558
#   Area           0
#   Price          0
# Bedrooms       529
# Bathrooms      289
# Wardrobes     3778
# Cabinets      3333
# Balcony       3725
# Parking       1579
# Quarters      1979
# dtype: int64

# %%
def plot_missing_values(data):
    """
    Shows the distribution of the non-missing vs mising values.
    """
    plt.figure(figsize=(10, 5))
    plt.title('Distribution of Missing Values')
    sns.heatmap(df.isnull(),cbar=False)

# %%
plot_missing_values(df)

# %%
df.columns
# Out:
# Index(['  Location', '  Area', '  Price', 'Bedrooms', 'Bathrooms', 'Wardrobes',
#        'Cabinets', 'Balcony', 'Parking', 'Quarters'],
#       dtype='object')

# %%
df['Area']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Area'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df['Area']
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'Area'

# %%
df.columns = [col.strip().lower() for col in df.columns]

# %%
df['area'].value_counts().head(30)
# Out:
# area
#  sqm        1809
# 25/30 m      730
# 20/30 m      494
# 25/20 m      232
# 30/20 m      158
# 20/25 m      151
# 30/30 m      143
# 30/25 m      134
# 25/25 m      106
# 35/30 m       61
# 28/30 m       59
# 25/35 m       57
# 600 sqm       46
# 20/20 m       44
# 30/35 m       44
# 500 sqm       42
# 30/40 m       34
# 15/20 m       32
# 3338 sqm      29
# 400 sqm       24
# 750 sqm       17
# 40/30 m       16
# 20/15 m       15
# 1300 sqm      11
# 35/40 m       11
# 20/35 m        9
# 20 sqm         9
# 700 sqm        8
# 944 sqm        8
# 22/25 m        7
# Name: count, dtype: int64

# %%
def clean_area(area):
    remove_sqm = area.replace('sqm', '').replac

# %%
df['area'].head(30)
# Out:
# 0     25/35 m
# 1         sqm
# 2     25/30 m
# 3         sqm
# 4         sqm
# 5     20/30 m
# 6     35/30 m
# 7     545 sqm
# 8     600 sqm
# 9         sqm
# 10    25/30 m
# 11    25/30 m
# 12        sqm
# 13    25/20 m
# 14    20/30 m
# 15    25/30 m
# 16        sqm
# 17        sqm
# 18        sqm
# 19    25/30 m
# 20    22/30 m
# 21    25/25 m
# 22        sqm
# 23        sqm
# 24    30/30 m
# 25        sqm
# 26        sqm
# 27    25/30 m
# 28        sqm
# 29        sqm
# Name: area, dtype: object

# %%
def clean_area(area):
    remove_m_sqm = area.replace(' m', '').replace(' sqm', '').replace('sqm', '')
    if remove_m_sqm == '':
        return None
    elif '/' in remove_m_sqm:
        wl = remove_m_sqm.split('/')
        return int(wl[0]) * int(wl[1])
    else:
        return int(remove_m_sqm)

# %%
df['cleaned_areas'] = df['area'].apply(clean_area)

# %%
df
# Out:
#        location     area             price  bedrooms  bathrooms wardrobes  \
# 0      Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0       NaN
# 1      Gacuriro      sqm  180 000 000  Rwf       4.0        4.0       NaN
# 2        Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0       NaN
# 3           NaN      sqm    8 500 000  Rwf       3.0        NaN       NaN
# 4     Kimironko      sqm   28 000 000  Rwf       4.0        3.0       Yes
# ...         ...      ...               ...       ...        ...       ...
# 4794    Kanombe      sqm   52 000 000  Rwf       4.0        3.0       NaN
# 4795        NaN  500 sqm   14 000 000  Rwf       5.0        2.0       NaN
# 4796    Rugende  945 sqm   28 500 000  Rwf       5.0        3.0       NaN
# 4797     Kabuga  30/20 m   15 000 000  Rwf       4.0        1.0       Yes
# 4798     Kabuga      sqm   30 000 000  Rwf       3.0        2.0       NaN
#
#      cabinets balcony parking quarters cleaned_area  cleaned_areas
# 0         NaN     NaN     Yes      Yes          NaN          875.0
# 1         NaN     Yes     NaN      NaN          NaN            NaN
# 2         NaN     NaN     NaN      NaN          NaN          750.0
# 3         NaN     NaN     NaN      NaN          NaN            NaN
# 4         Yes     Yes     Yes      Yes          NaN            NaN
# ...       ...     ...     ...      ...          ...            ...
# 4794      Yes     NaN     NaN      NaN         <NA>            NaN
# 4795      NaN     Yes     NaN      Yes          500          500.0
# 4796      NaN     NaN     NaN      NaN          945          945.0
# 4797      Yes     Yes     Yes      NaN         <NA>          600.0
# 4798      NaN     Yes     NaN      NaN         <NA>            NaN
#
# [4799 rows x 12 columns]

# %% [markdown]
# # Function to clean prices

# %%
def clean_price(price):
    cleaned_price = price.replace(' Rwf', '').replace(' $', '').replace(' ', '').replace('nanNegotiable', '')
    remove_space = cleaned_price.strip()
    return remove_space

# %% [markdown]
# ### Proper one

# %%
def clean_price(price):

    if ' Rwf' in price:
        return int(price.replace(' Rwf', '').replace(' ', ''))

    elif ' $' in price:
        return int(price.replace(' $', '').replace(' ', '')) * 1300
    # cleaned_price = price.replace(' Rwf', '').replace(' $', '').replace(' ', '').replace('nanNegotiable', '')
    # remove_space = cleaned_price.strip()
    else:
        return None

# %%
df['cleaned_price'] = df['price'].apply(clean_price)

# %%
df
# Out:
#        location     area             price  bedrooms  bathrooms wardrobes  \
# 0      Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0       NaN
# 1      Gacuriro      sqm  180 000 000  Rwf       4.0        4.0       NaN
# 2        Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0       NaN
# 3           NaN      sqm    8 500 000  Rwf       3.0        NaN       NaN
# 4     Kimironko      sqm   28 000 000  Rwf       4.0        3.0       Yes
# ...         ...      ...               ...       ...        ...       ...
# 4794    Kanombe      sqm   52 000 000  Rwf       4.0        3.0       NaN
# 4795        NaN  500 sqm   14 000 000  Rwf       5.0        2.0       NaN
# 4796    Rugende  945 sqm   28 500 000  Rwf       5.0        3.0       NaN
# 4797     Kabuga  30/20 m   15 000 000  Rwf       4.0        1.0       Yes
# 4798     Kabuga      sqm   30 000 000  Rwf       3.0        2.0       NaN
#
#      cabinets balcony parking quarters cleaned_area  cleaned_areas  \
# 0         NaN     NaN     Yes      Yes          NaN          875.0
# 1         NaN     Yes     NaN      NaN          NaN            NaN
# 2         NaN     NaN     NaN      NaN          NaN          750.0
# 3         NaN     NaN     NaN      NaN          NaN            NaN
# 4         Yes     Yes     Yes      Yes          NaN            NaN
# ...       ...     ...     ...      ...          ...            ...
# 4794      Yes     NaN     NaN      NaN         <NA>            NaN
# 4795      NaN     Yes     NaN      Yes          500          500.0
# 4796      NaN     NaN     NaN      NaN          945          945.0
# 4797      Yes     Yes     Yes      NaN         <NA>          600.0
# 4798      NaN     Yes     NaN      NaN         <NA>            NaN
#
#       cleaned_price
# 0        55000000.0
# 1       180000000.0
# 2        45000000.0
# 3         8500000.0
# 4        28000000.0
# ...             ...
# 4794     52000000.0
# 4795     14000000.0
# 4796     28500000.0
# 4797     15000000.0
# 4798     30000000.0
#
# [4799 rows x 13 columns]

# %%
df['cleaned_price'].astype(float)
# Out:
# 0        55000000.0
# 1       180000000.0
# 2        45000000.0
# 3         8500000.0
# 4        28000000.0
#            ...
# 4794     52000000.0
# 4795     14000000.0
# 4796     28500000.0
# 4797     15000000.0
# 4798     30000000.0
# Name: cleaned_price, Length: 4799, dtype: float64

# %%
df['cleaned_price'].head(60)
# Out:
# 0      55000000
# 1     180000000
# 2      45000000
# 3       8500000
# 4      28000000
# 5      42000000
# 6      50000000
# 7      22000000
# 8      45000000
# 9      60000000
# 10    150000000
# 11     45000000
# 12     75000000
# 13     38000000
# 14     50000000
# 15    150000000
# 16     90000000
# 17     10000000
# 18     60000000
# 19     45000000
# 20     55000000
# 21    120000000
# 22     55000000
# 23     45000000
# 24     95000000
# 25     50000000
# 26     68000000
# 27     75000000
# 28     45000000
# 29     55000000
# 30     60000000
# 31    130000000
# 32     70000000
# 33     40000000
# 34     47000000
# 35    350000000
# 36         2500
# 37     60000000
# 38    160000000
# 39     26000000
# 40     65000000
# 41     12000000
# 42    110000000
# 43     10000000
# 44     35000000
# 45
# 46    120000000
# 47     15000000
# 48    100000000
# 49     55000000
# 50     52000000
# 51    100000000
# 52    350000000
# 53     55000000
# 54     75000000
# 55     70000000
# 56    150000000
# 57     90000000
# 58     25000000
# 59     25000000
# Name: cleaned_price, dtype: object

# %% [markdown]
# ## Tuesday

# %%
df
# Out:
#        location     area             price  bedrooms  bathrooms wardrobes  \
# 0      Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0       NaN
# 1      Gacuriro      sqm  180 000 000  Rwf       4.0        4.0       NaN
# 2        Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0       NaN
# 3           NaN      sqm    8 500 000  Rwf       3.0        NaN       NaN
# 4     Kimironko      sqm   28 000 000  Rwf       4.0        3.0       Yes
# ...         ...      ...               ...       ...        ...       ...
# 4794    Kanombe      sqm   52 000 000  Rwf       4.0        3.0       NaN
# 4795        NaN  500 sqm   14 000 000  Rwf       5.0        2.0       NaN
# 4796    Rugende  945 sqm   28 500 000  Rwf       5.0        3.0       NaN
# 4797     Kabuga  30/20 m   15 000 000  Rwf       4.0        1.0       Yes
# 4798     Kabuga      sqm   30 000 000  Rwf       3.0        2.0       NaN
#
#      cabinets balcony parking quarters cleaned_area  cleaned_areas  \
# 0         NaN     NaN     Yes      Yes          NaN          875.0
# 1         NaN     Yes     NaN      NaN          NaN            NaN
# 2         NaN     NaN     NaN      NaN          NaN          750.0
# 3         NaN     NaN     NaN      NaN          NaN            NaN
# 4         Yes     Yes     Yes      Yes          NaN            NaN
# ...       ...     ...     ...      ...          ...            ...
# 4794      Yes     NaN     NaN      NaN         <NA>            NaN
# 4795      NaN     Yes     NaN      Yes          500          500.0
# 4796      NaN     NaN     NaN      NaN          945          945.0
# 4797      Yes     Yes     Yes      NaN         <NA>          600.0
# 4798      NaN     Yes     NaN      NaN         <NA>            NaN
#
#       cleaned_price
# 0        55000000.0
# 1       180000000.0
# 2        45000000.0
# 3         8500000.0
# 4        28000000.0
# ...             ...
# 4794     52000000.0
# 4795     14000000.0
# 4796     28500000.0
# 4797     15000000.0
# 4798     30000000.0
#
# [4799 rows x 13 columns]

# %%
df['location'].value_counts()
# Out:
# location
# Kanombe        814
# Kibagabaga     658
# Kimironko      524
# Kicukiro       423
# Gacuriro       216
#               ...
# S                1
# Gisimenti        1
# Kianombe         1
# Residential      1
# Kicukiri         1
# Name: count, Length: 118, dtype: int64

# %%
neighborhoods = {'Fawe':'Gisozi','Gaposho':'Gisozi', 'Niboye':'Niboyi','Kibagaba':'Kibagabaga','Kimiromko':'Kimironko',
                 'Rusororo':'Kabuga/Ndera/Rusororo','Ndera':'Kabuga/Ndera/Rusororo', 'Kabuga':'Kabuga/Ndera/Rusororo',
                 'Murindi':'Kabuga/Ndera/Rusororo', 'Gasogi':'Kabuga/Ndera/Rusororo', 'Rdb':'Nyarutarama', 'Niboye':'Niboyi',
                 'Kibagababa':'Kibagabaga', 'Gishushu':'Nyarutarama','Masizi':'Zindiro', 'Karembure':'Gahanga',
                'Gatenga':'Gatenga/Gikondo','Gikondo':'Gatenga/Gikondo','Kibagaba':'Kibagabaga'}

# %%
df['clean_location'] = df['location'].replace(neighborhoods)

# %%
df.head(5)
# Out:
#     location     area             price  bedrooms  bathrooms wardrobes  \
# 0   Kinyinya  25/35 m   55 000 000  Rwf       4.0        1.0       NaN
# 1   Gacuriro      sqm  180 000 000  Rwf       4.0        4.0       NaN
# 2     Kabeza  25/30 m   45 000 000  Rwf       4.0        3.0       NaN
# 3        NaN      sqm    8 500 000  Rwf       3.0        NaN       NaN
# 4  Kimironko      sqm   28 000 000  Rwf       4.0        3.0       Yes
#
#   cabinets balcony parking quarters cleaned_area  cleaned_areas  \
# 0      NaN     NaN     Yes      Yes         <NA>          875.0
# 1      NaN     Yes     NaN      NaN         <NA>            NaN
# 2      NaN     NaN     NaN      NaN         <NA>          750.0
# 3      NaN     NaN     NaN      NaN         <NA>            NaN
# 4      Yes     Yes     Yes      Yes         <NA>            NaN
#
#    cleaned_price clean_location
# 0     55000000.0       Kinyinya
# 1    180000000.0       Gacuriro
# 2     45000000.0         Kabeza
# 3      8500000.0            NaN
# 4     28000000.0      Kimironko

# %%
df['clean_location'].value_counts().head(60)
# Out:
# clean_location
# Kanombe                  814
# Kibagabaga               671
# Kimironko                532
# Kicukiro                 423
# Gacuriro                 216
# Gisozi                   180
# Kabeza                   158
# Kabuga/Ndera/Rusororo    141
# Kagarama                 117
# Gatenga/Gikondo          113
# Remera                   104
# Masaka                   101
# Nyarutarama               79
# Kagugu                    53
# Nyamata                   50
# Kacyiru                   43
# Kinyinya                  35
# Kiyovu                    34
# Niboyi                    30
# Zindiro                   30
# Kimihurura                27
# Nyamirambo                25
# Gahanga                   22
# Rebero                    20
# Karuruma                  15
# Gasanze                   12
# Muyumbu                   12
# Karumuna                  12
# Gasabo                    11
# Ruyenzi                   10
# Rugende                    8
# Bumbogo                    6
# Jali                       6
# Akagera                    5
# Kanzenze                   5
# Gihogwe                    5
# Airport                    5
# Gatsata                    4
# Kigalisibo                 4
# Gasaraba                   4
# Price                      3
# Kigalikibagabag            3
# Caiman                     3
# Modern                     3
# Ulk                        3
# Apartment                  3
# Gisenyi                    3
# Rusheshe                   3
# Bugesera                   3
# Kwirebero                  2
# Nyagatare                  2
# Nibonyi                    2
# Kanserege                  2
# Busanza                    2
# Just                       2
# Rusizi                     2
# Rwamagana                  2
# Rpf                        2
# Nyabikenke                 2
# Kigugu                     2
# Name: count, dtype: int64

# %%
df['clean_location'][df['clean_location'].value_counts().values >= 30]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[102], line 1
# ----> 1 df['clean_location'][df['clean_location'].value_counts().values >= 30]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1068, in Series.__getitem__(self, key)
#    1065     return self._getitem_slice(key)
#    1067 if com.is_bool_indexer(key):
# -> 1068     key = check_bool_indexer(self.index, key)
#    1069     key = np.asarray(key, dtype=bool)
#    1070     return self._get_rows_with_mask(key)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexing.py:2594, in check_bool_indexer(index, key)
#    2590 elif not is_array_like(result):
#    2591     # GH 33924
#    2592     # key may contain nan elements, check_array_indexer needs bool array
#    2593     result = pd_array(result, dtype=bool)
# -> 2594 return check_array_indexer(index, result)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexers\utils.py:539, in check_array_indexer(array, indexer)
#     537     # GH26658
#     538     if len(indexer) != len(array):
# --> 539         raise IndexError(
#     540             f"Boolean index has wrong length: "
#     541             f"{len(indexer)} instead of {len(array)}"
#     542         )
#     543 elif is_integer_dtype(dtype):
#     544     try:
#
# IndexError: Boolean index has wrong length: 103 instead of 4799

# %%
more_30 = df['clean_location'].value_counts()[df['clean_location'].value_counts().values >= 30]

# %%
df['clean_location'].isin(more_30)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4794    False
# 4795    False
# 4796    False
# 4797    False
# 4798    False
# Name: clean_location, Length: 4799, dtype: bool

# %%
df['wardrobes'].fillna('No' , inplace = True)

# %%
plot_missing_values(df)

# %%
df['parking'].fillna('No' , inplace = True)
df['cabinets'].fillna('No' , inplace = True)
df['balcony'].fillna('No' , inplace = True)
df['quarters'].fillna('No' , inplace = True)

# %%
plot_missing_values(df)

# %%
test = pd.DataFrame({'Class':['Data Science',None,None,
                              'Data Engineering',None,None,
                             'Software Development',None,None],
                    'Students': ['A','B','C','D','E','F','G','H','J']})

# %%
test.to_csv('Students.csv', index = False)

# %%
test
# Out:
#                   Class Students
# 0          Data Science        A
# 1                  None        B
# 2                  None        C
# 3      Data Engineering        D
# 4                  None        E
# 5                  None        F
# 6  Software Development        G
# 7                  None        H
# 8                  None        J

# %%
test.fillna(method = 'ffill')
# Out:
# C:\Users\educa\AppData\Local\Temp\ipykernel_11856\851048705.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   test.fillna(method = 'ffill')
#                   Class Students
# 0          Data Science        A
# 1          Data Science        B
# 2          Data Science        C
# 3      Data Engineering        D
# 4      Data Engineering        E
# 5      Data Engineering        F
# 6  Software Development        G
# 7  Software Development        H
# 8  Software Development        J

# %%
test.bfill()
# Out:
#                   Class Students
# 0          Data Science        A
# 1      Data Engineering        B
# 2      Data Engineering        C
# 3      Data Engineering        D
# 4  Software Development        E
# 5  Software Development        F
# 6  Software Development        G
# 7                  None        H
# 8                  None        J

# %%
plot_missing_values(df)

# %%
cleaned = df[['area', 'price', 'bedrooms', 'wardrobes', 'cabinets', 'balcony', 'parking', 'quarters', 'cleaned_areas', 'cleaned_price', 'clean_location']]

# %%
cleaned.head(3)
# Out:
#       area             price  bedrooms wardrobes cabinets balcony parking  \
# 0  25/35 m   55 000 000  Rwf       4.0        No       No      No     Yes
# 1      sqm  180 000 000  Rwf       4.0        No       No     Yes      No
# 2  25/30 m   45 000 000  Rwf       4.0        No       No      No      No
#
#   quarters  cleaned_areas  cleaned_price clean_location
# 0      Yes          875.0     55000000.0       Kinyinya
# 1       No            NaN    180000000.0       Gacuriro
# 2       No          750.0     45000000.0         Kabeza

# %%
cleaned.dropna(inplace = True)
# Out:
# C:\Users\educa\AppData\Local\Temp\ipykernel_11856\213288612.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned.dropna(inplace = True)

# %%
cleaned
# Out:
#          area             price  bedrooms wardrobes cabinets balcony parking  \
# 0     25/35 m   55 000 000  Rwf       4.0        No       No      No     Yes
# 2     25/30 m   45 000 000  Rwf       4.0        No       No      No      No
# 6     35/30 m   50 000 000  Rwf       4.0        No       No      No      No
# 7     545 sqm   22 000 000  Rwf       4.0        No       No      No      No
# 10    25/30 m  150 000 000  Rwf       4.0        No       No      No      No
# ...       ...               ...       ...       ...      ...     ...     ...
# 4782   59 sqm          71 000 $       1.0        No       No     Yes     Yes
# 4783  30/20 m   45 000 000  Rwf       4.0       Yes      Yes     Yes     Yes
# 4791  25/25 m   65 000 000  Rwf       4.0        No       No      No     Yes
# 4796  945 sqm   28 500 000  Rwf       5.0        No       No      No      No
# 4797  30/20 m   15 000 000  Rwf       4.0       Yes      Yes     Yes     Yes
#
#      quarters  cleaned_areas  cleaned_price         clean_location
# 0         Yes          875.0     55000000.0               Kinyinya
# 2          No          750.0     45000000.0                 Kabeza
# 6          No         1050.0     50000000.0               Karumuna
# 7          No          545.0     22000000.0                 Rebero
# 10         No          750.0    150000000.0              Kimironko
# ...       ...            ...            ...                    ...
# 4782       No           59.0     92300000.0                 Gisozi
# 4783       No          600.0     45000000.0                Kanombe
# 4791      Yes          625.0     65000000.0               Kicukiro
# 4796       No          945.0     28500000.0                Rugende
# 4797       No          600.0     15000000.0  Kabuga/Ndera/Rusororo
#
# [2334 rows x 11 columns]

# %%
plot_missing_values(cleaned)

# %%
df.dropna(inplace = True)

# %%
plot_missing_values(df)

# %%
cleaaned = cleaned[cleaned['cleaned_price'] >= 10000000]
cleaaned = cleaned[cleaned['cleaned_areas'] >= 300]

# %%
df['bedrooms'].value_counts()
# Out:
# bedrooms
# 4.0        93
# 5.0        63
# 3.0        25
# 6.0        11
# 10.0        2
# 13003.0     2
# 1.0         2
# Name: count, dtype: int64

# %%
cleaaned['bedrooms'].value_counts()
# Out:
# bedrooms
# 4.0        1797
# 5.0         307
# 3.0         101
# 6.0          81
# 8.0          12
# 7.0           9
# 51.0          4
# 2.0           3
# 10.0          2
# 25.0          2
# 13003.0       2
# Name: count, dtype: int64

# %%
cleaaned['cleaned_areas'].plot(kind = 'box')
# Out:
# <Axes: >

# %% [markdown]
# # Interquarrtile range method

# %%
import numpy as np

# %%
np.percentile(cleaaned['cleaned_price'], 50)
# Out:
# 60000000.0

# %%
def outliers_bounds(df, column_name, lower_percentile=0, upper_percentile=100):

    column_values = df[column_name]
    lower_bound = np.percentile(column_values, lower_percentile)
    upper_bound = np.percentile(column_values, lower_percentile)

    return lower_bound, upper_bound



# def calculate_bounds(dataframe, column_name, lower_percentile=0, upper_percentile=100):
#     """
#     Calculate the lower and upper bounds of a column in a pandas DataFrame using percentile.

#     Parameters:
#         dataframe (DataFrame): The pandas DataFrame containing the data.
#         column_name (str): The name of the column for which bounds are to be calculated.
#         lower_percentile (float): The percentile value for the lower bound (default is 0).
#         upper_percentile (float): The percentile value for the upper bound (default is 100).

#     Returns:
#         float, float: The lower and upper bounds of the column.
#     """
#

# %%
lower_bound, upper_bound = outliers_bounds(cleaaned, 'cleaned_price')
print("Lower Bound:", lower_bound)
print("Upper Bound:", upper_bound)
# Out:
# Lower Bound: 429000.0
# Upper Bound: 429000.0

# %%
def outliers_bounds(df, column_name):

    values = df[column_name]
    q1 = np.percentile(values, 25)
    q3 = np.percentile(values, 75)
    iqr = q3 -q1
    co = iqr * 1.5
    lower_bound = q1 - co
    upper_bound = q3 + co

    return lower_bound, upper_bound

# %%
outliers_bounds(cleaaned, 'cleaned_areas')
# Out:
# (375.0, 975.0)

# %%
area_bounds = outliers_bounds(cleaaned, 'cleaned_areas')

# %%
area_bounds
# Out:
# (375.0, 975.0)

# %%
cleaner = cleaaned[(cleaaned['cleaned_areas'] >= area_bounds[0]) & (cleaaned['cleaned_areas'] <= area_bounds[1])]

# %%
cleaner.head(3)
# Out:
#       area            price  bedrooms wardrobes cabinets balcony parking  \
# 0  25/35 m  55 000 000  Rwf       4.0        No       No      No     Yes
# 2  25/30 m  45 000 000  Rwf       4.0        No       No      No      No
# 7  545 sqm  22 000 000  Rwf       4.0        No       No      No      No
#
#   quarters  cleaned_areas  cleaned_price clean_location
# 0      Yes          875.0     55000000.0       Kinyinya
# 2       No          750.0     45000000.0         Kabeza
# 7       No          545.0     22000000.0         Rebero

# %%
price_bounds = outliers_bounds(cleaaned, 'cleaned_price')

# %%
price_bounds
# Out:
# (-17500000.0, 154500000.0)

# %%
cleaaned['cleaned_price'].sort_values(ascending = False)
# Out:
# 3797    3.770000e+11
# 2025    3.770000e+11
# 2318    2.340000e+10
# 3322    1.950000e+10
# 2162    1.950000e+10
#             ...
# 36      3.250000e+06
# 4740    3.250000e+06
# 3177    3.250000e+06
# 3850    3.000000e+06
# 4482    4.290000e+05
# Name: cleaned_price, Length: 2320, dtype: float64

# %%
cleaner = cleaner[(cleaner['cleaned_price'] >= price_bounds[0]) & (cleaner['cleaned_price'] <= price_bounds[1])]

# %%
cleaner.head(3)
# Out:
#       area            price  bedrooms wardrobes cabinets balcony parking  \
# 0  25/35 m  55 000 000  Rwf       4.0        No       No      No     Yes
# 2  25/30 m  45 000 000  Rwf       4.0        No       No      No      No
# 7  545 sqm  22 000 000  Rwf       4.0        No       No      No      No
#
#   quarters  cleaned_areas  cleaned_price clean_location
# 0      Yes          875.0     55000000.0       Kinyinya
# 2       No          750.0     45000000.0         Kabeza
# 7       No          545.0     22000000.0         Rebero

# %% [markdown]
# # Wednesday

# %% [markdown]
# ## Creating bins

# %%
cleaner['area category'] = pd.cut(cleaner['cleaned_areas'], bins = [300, 399, 499, 599, 699, 799, 899, 999], labels = ['300-400', '400-500', '500-600', '600-700', '700-800', '800-900', '900+'])
# Out:
# C:\Users\educa\AppData\Local\Temp\ipykernel_11856\3623370850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaner['area category'] = pd.cut(cleaner['cleaned_areas'], bins = [300, 399, 499, 599, 699, 799, 899, 999], labels = ['300-400', '400-500', '500-600', '600-700', '700-800', '800-900', '900+'])

# %%
cleaner.columns
# Out:
# Index(['area', 'price', 'bedrooms', 'wardrobes', 'cabinets', 'balcony',
#        'parking', 'quarters', 'cleaned_areas', 'cleaned_price',
#        'clean_location', 'area category'],
#       dtype='object')

# %%
cleaner[['bedrooms', 'wardrobes', 'cabinets', 'balcony',
       'parking', 'quarters', 'cleaned_areas', 'cleaned_price',
       'clean_location', 'area category']]
# Out:
#       bedrooms wardrobes cabinets balcony parking quarters  cleaned_areas  \
# 0          4.0        No       No      No     Yes      Yes          875.0
# 2          4.0        No       No      No      No       No          750.0
# 7          4.0        No       No      No      No       No          545.0
# 10         4.0        No       No      No      No       No          750.0
# 14         4.0        No       No      No     Yes      Yes          600.0
# ...        ...       ...      ...     ...     ...      ...            ...
# 4780       5.0        No       No      No     Yes      Yes          600.0
# 4783       4.0       Yes      Yes     Yes     Yes       No          600.0
# 4791       4.0        No       No      No     Yes      Yes          625.0
# 4796       5.0        No       No      No      No       No          945.0
# 4797       4.0       Yes      Yes     Yes     Yes       No          600.0
#
#       cleaned_price         clean_location area category
# 0        55000000.0               Kinyinya       800-900
# 2        45000000.0                 Kabeza       700-800
# 7        22000000.0                 Rebero       500-600
# 10      150000000.0              Kimironko       700-800
# 14       50000000.0                 Gisozi       600-700
# ...             ...                    ...           ...
# 4780     85000000.0             Kibagabaga       600-700
# 4783     45000000.0                Kanombe       600-700
# 4791     65000000.0               Kicukiro       600-700
# 4796     28500000.0                Rugende          900+
# 4797     15000000.0  Kabuga/Ndera/Rusororo       600-700
#
# [1932 rows x 10 columns]

# %%
cleaned_final = cleaner[['bedrooms', 'wardrobes', 'cabinets', 'balcony',
       'parking', 'quarters', 'cleaned_areas', 'cleaned_price',
       'clean_location', 'area category']]

# %%
cleaned_final.head(3)
# Out:
#    bedrooms wardrobes cabinets balcony parking quarters  cleaned_areas  \
# 0       4.0        No       No      No     Yes      Yes          875.0
# 2       4.0        No       No      No      No       No          750.0
# 7       4.0        No       No      No      No       No          545.0
#
#    cleaned_price clean_location area category
# 0     55000000.0       Kinyinya       800-900
# 2     45000000.0         Kabeza       700-800
# 7     22000000.0         Rebero       500-600

# %%
cleaned_final.columns = [col.replace('cleaned_', '').replace('clean_', '').replace(' category', '') for col in cleaned_final.columns]

# %%
cleaned_final.head(3)
# Out:
#    bedrooms wardrobes cabinets balcony parking quarters  areas       price  \
# 0       4.0        No       No      No     Yes      Yes  875.0  55000000.0
# 2       4.0        No       No      No      No       No  750.0  45000000.0
# 7       4.0        No       No      No      No       No  545.0  22000000.0
#
#    location     area
# 0  Kinyinya  800-900
# 2    Kabeza  700-800
# 7    Rebero  500-600

# %% [markdown]
# ## Creating dummies (Encoding categorical value into numerical values)

# %%
pd.get_dummies(cleaned_final[['location', 'parking']], dtype = int)
# Out:
#       location_Airport  location_Arena  location_Bibare  location_Caiman  \
# 0                    0               0                0                0
# 2                    0               0                0                0
# 7                    0               0                0                0
# 10                   0               0                0                0
# 14                   0               0                0                0
# ...                ...             ...              ...              ...
# 4780                 0               0                0                0
# 4783                 0               0                0                0
# 4791                 0               0                0                0
# 4796                 0               0                0                0
# 4797                 0               0                0                0
#
#       location_Gacurilo  location_Gacuriro  location_Gahanga  \
# 0                     0                  0                 0
# 2                     0                  0                 0
# 7                     0                  0                 0
# 10                    0                  0                 0
# 14                    0                  0                 0
# ...                 ...                ...               ...
# 4780                  0                  0                 0
# 4783                  0                  0                 0
# 4791                  0                  0                 0
# 4796                  0                  0                 0
# 4797                  0                  0                 0
#
#       location_Gasaraba  location_Gatenga/Gikondo  location_Gihogwe  ...  \
# 0                     0                         0                 0  ...
# 2                     0                         0                 0  ...
# 7                     0                         0                 0  ...
# 10                    0                         0                 0  ...
# 14                    0                         0                 0  ...
# ...                 ...                       ...               ...  ...
# 4780                  0                         0                 0  ...
# 4783                  0                         0                 0  ...
# 4791                  0                         0                 0  ...
# 4796                  0                         0                 0  ...
# 4797                  0                         0                 0  ...
#
#       location_Nyamirambo  location_Nyarutarama  location_Rebero  \
# 0                       0                     0                0
# 2                       0                     0                0
# 7                       0                     0                1
# 10                      0                     0                0
# 14                      0                     0                0
# ...                   ...                   ...              ...
# 4780                    0                     0                0
# 4783                    0                     0                0
# 4791                    0                     0                0
# 4796                    0                     0                0
# 4797                    0                     0                0
#
#       location_Remera  location_Rugende  location_Rusizi  location_Ruyenzi  \
# 0                   0                 0                0                 0
# 2                   0                 0                0                 0
# 7                   0                 0                0                 0
# 10                  0                 0                0                 0
# 14                  0                 0                0                 0
# ...               ...               ...              ...               ...
# 4780                0                 0                0                 0
# 4783                0                 0                0                 0
# 4791                0                 0                0                 0
# 4796                0                 1                0                 0
# 4797                0                 0                0                 0
#
#       location_Zindiro  parking_No  parking_Yes
# 0                    0           0            1
# 2                    0           1            0
# 7                    0           1            0
# 10                   0           1            0
# 14                   0           0            1
# ...                ...         ...          ...
# 4780                 0           0            1
# 4783                 0           0            1
# 4791                 0           0            1
# 4796                 0           1            0
# 4797                 0           0            1
#
# [1932 rows x 48 columns]

# %% [markdown]
# def create_dummies(df, numerical_columns, dummy_columns):
#
#     values = cleaned_final['column_name']
#     dummies = pd.get_dummies(values, dtype = int)
#
#     return dummies
#
#
# def create_dummies(df, categorical_columns):
#     dummies = pd.get_dummies(df[categorical_columns], dtype=int)
#     return dummies

# %%
def create_dummies(df, numerical_columns, dummy_columns):

    numerical_df = df[numerical_columns]
    dummy_df = pd.get_dummies(df[dummy_columns], dtype = int)
    
    numerical_dummies = pd.concat([numerical_df, dummy_df], axis = 1)
    
    return numerical_dummies

# %%
numerical = ['price', 'bedrooms']
non_numerical = [col for col in cleaned_final.columns if col not in numerical]

final_df = create_dummies(cleaned_final, numerical, non_numerical)

# %%
final_df
# Out:
#             price  bedrooms  areas  wardrobes_No  wardrobes_Yes  cabinets_No  \
# 0      55000000.0       4.0  875.0             1              0            1
# 2      45000000.0       4.0  750.0             1              0            1
# 7      22000000.0       4.0  545.0             1              0            1
# 10    150000000.0       4.0  750.0             1              0            1
# 14     50000000.0       4.0  600.0             1              0            1
# ...           ...       ...    ...           ...            ...          ...
# 4780   85000000.0       5.0  600.0             1              0            1
# 4783   45000000.0       4.0  600.0             0              1            0
# 4791   65000000.0       4.0  625.0             1              0            1
# 4796   28500000.0       5.0  945.0             1              0            1
# 4797   15000000.0       4.0  600.0             0              1            0
#
#       cabinets_Yes  balcony_No  balcony_Yes  parking_No  ...  location_Rusizi  \
# 0                0           1            0           0  ...                0
# 2                0           1            0           1  ...                0
# 7                0           1            0           1  ...                0
# 10               0           1            0           1  ...                0
# 14               0           1            0           0  ...                0
# ...            ...         ...          ...         ...  ...              ...
# 4780             0           1            0           0  ...                0
# 4783             1           0            1           0  ...                0
# 4791             0           1            0           0  ...                0
# 4796             0           1            0           1  ...                0
# 4797             1           0            1           0  ...                0
#
#       location_Ruyenzi  location_Zindiro  area_300-400  area_400-500  \
# 0                    0                 0             0             0
# 2                    0                 0             0             0
# 7                    0                 0             0             0
# 10                   0                 0             0             0
# 14                   0                 0             0             0
# ...                ...               ...           ...           ...
# 4780                 0                 0             0             0
# 4783                 0                 0             0             0
# 4791                 0                 0             0             0
# 4796                 0                 0             0             0
# 4797                 0                 0             0             0
#
#       area_500-600  area_600-700  area_700-800  area_800-900  area_900+
# 0                0             0             0             1          0
# 2                0             0             1             0          0
# 7                1             0             0             0          0
# 10               0             0             1             0          0
# 14               0             1             0             0          0
# ...            ...           ...           ...           ...        ...
# 4780             0             1             0             0          0
# 4783             0             1             0             0          0
# 4791             0             1             0             0          0
# 4796             0             0             0             0          1
# 4797             0             1             0             0          0
#
# [1932 rows x 66 columns]

# %% [markdown]
# # MODELLING

# %% [markdown]
# ## CHOOSE THE MODEL AND PERFORMANCE METRICS

# %% [markdown]
# ### 1 REGRESSION

# %%
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.linear_model import LinearRegression

# %%
r2_score([200, 300, 400],
                   [195, 290, 360])
# Out:
# 0.9137500000000001

# %% [markdown]
# # Thursday

# %% [markdown]
# ## Split the dataset into training and testing data

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
features = final_df.drop(['price'], axis = 1)

# %%
features.head(3)
# Out:
#    bedrooms  areas  wardrobes_No  wardrobes_Yes  cabinets_No  cabinets_Yes  \
# 0       4.0  875.0             1              0            1             0
# 2       4.0  750.0             1              0            1             0
# 7       4.0  545.0             1              0            1             0
#
#    balcony_No  balcony_Yes  parking_No  parking_Yes  ...  location_Rusizi  \
# 0           1            0           0            1  ...                0
# 2           1            0           1            0  ...                0
# 7           1            0           1            0  ...                0
#
#    location_Ruyenzi  location_Zindiro  area_300-400  area_400-500  \
# 0                 0                 0             0             0
# 2                 0                 0             0             0
# 7                 0                 0             0             0
#
#    area_500-600  area_600-700  area_700-800  area_800-900  area_900+
# 0             0             0             0             1          0
# 2             0             0             1             0          0
# 7             1             0             0             0          0
#
# [3 rows x 65 columns]

# %%
target = final_df[['price']]

# %%
target.head(3)
# Out:
#         price
# 0  55000000.0
# 2  45000000.0
# 7  22000000.0

# %%
train_features, test_features, train_target, test_target = train_test_split(features, target, test_size = 0.2, random_state = 1)

# %%
test_features.head(3)
# Out:
#       bedrooms  areas  wardrobes_No  wardrobes_Yes  cabinets_No  cabinets_Yes  \
# 760        4.0  600.0             0              1            0             1
# 1701       4.0  625.0             1              0            1             0
# 4182       4.0  500.0             1              0            1             0
#
#       balcony_No  balcony_Yes  parking_No  parking_Yes  ...  location_Rusizi  \
# 760            0            1           0            1  ...                0
# 1701           1            0           0            1  ...                0
# 4182           1            0           0            1  ...                0
#
#       location_Ruyenzi  location_Zindiro  area_300-400  area_400-500  \
# 760                  0                 0             0             0
# 1701                 0                 0             0             0
# 4182                 0                 0             0             0
#
#       area_500-600  area_600-700  area_700-800  area_800-900  area_900+
# 760              0             1             0             0          0
# 1701             0             1             0             0          0
# 4182             1             0             0             0          0
#
# [3 rows x 65 columns]

# %% [markdown]
# # Key steps in creating the model
# ## INSTANTIATE THE MODEL
# ## FIT THE MODEL
# ## TEST THE MODEL
# ## ACCESS THE PERFORMANCE OF THE MODEL

# %% [markdown]
# ### Instantiation

# %%
model = LinearRegression()

# %% [markdown]
# ### Fitting

# %%
model.fit(train_features, train_target)
# Out:
# LinearRegression()

# %% [markdown]
# ### Test/ Predict

# %%
predictions = model.predict(test_features)

# %%
predictions
# Out:
# array([[6.17170169e+07],
#        [6.62795614e+07],
#        [4.64943585e+07],
#        [5.63678032e+07],
#        [7.36345653e+07],
#        [8.98515943e+07],
#        [6.05288035e+07],
#        [4.58452306e+07],
#        [7.36345653e+07],
#        [8.10633746e+07],
#        [6.88514770e+07],
#        [5.44413186e+07],
#        [5.18941356e+07],
#        [7.36345653e+07],
#        [8.33145717e+07],
#        [4.72736265e+07],
#        [2.63494694e+07],
#        [1.15872064e+08],
#        [7.36345653e+07],
#        [1.11556056e+08],
#        [1.11556056e+08],
#        [7.34393417e+07],
#        [1.29322030e+08],
#        [4.56530989e+07],
#        [6.50384773e+07],
#        [5.08754665e+07],
#        [8.98515943e+07],
#        [5.44413186e+07],
#        [9.41676022e+07],
#        [5.44413186e+07],
#        [6.17994861e+07],
#        [4.39831439e+07],
#        [6.21217531e+07],
#        [8.57089113e+07],
#        [5.88567058e+07],
#        [6.51759624e+07],
#        [4.56288959e+07],
#        [5.44413186e+07],
#        [5.44413186e+07],
#        [6.13629628e+07],
#        [6.51759624e+07],
#        [6.50384773e+07],
#        [4.31418843e+07],
#        [8.98515943e+07],
#        [8.00000000e+07],
#        [5.53775184e+07],
#        [9.16635121e+07],
#        [8.98515943e+07],
#        [3.53870559e+07],
#        [8.62857422e+07],
#        [1.11556056e+08],
#        [7.36345653e+07],
#        [6.52828690e+07],
#        [6.16101104e+07],
#        [2.44920107e+07],
#        [6.88514770e+07],
#        [8.18221650e+07],
#        [5.44413186e+07],
#        [6.88514770e+07],
#        [8.55715142e+07],
#        [9.39894290e+07],
#        [9.07877941e+07],
#        [5.19599462e+07],
#        [4.64943585e+07],
#        [6.39669099e+07],
#        [8.19046342e+07],
#        [1.80000000e+07],
#        [6.09045169e+07],
#        [5.99069063e+07],
#        [5.09579357e+07],
#        [6.13629628e+07],
#        [1.11556056e+08],
#        [5.07658040e+07],
#        [6.14964731e+07],
#        [6.16101104e+07],
#        [7.36345653e+07],
#        [7.12561432e+07],
#        [6.88514770e+07],
#        [6.16101104e+07],
#        [6.21217531e+07],
#        [8.98515943e+07],
#        [7.87959786e+07],
#        [5.13932875e+07],
#        [4.56288959e+07],
#        [5.23084289e+07],
#        [1.03301560e+08],
#        [4.70863147e+07],
#        [5.44413186e+07],
#        [9.53390267e+07],
#        [8.98515943e+07],
#        [6.88514770e+07],
#        [8.98515943e+07],
#        [3.09299102e+07],
#        [6.78912848e+07],
#        [9.16635121e+07],
#        [7.66202639e+07],
#        [7.36345653e+07],
#        [8.98515943e+07],
#        [7.67919291e+07],
#        [1.11871271e+07],
#        [5.64235234e+07],
#        [5.07658040e+07],
#        [4.70863147e+07],
#        [7.10873823e+07],
#        [6.21217531e+07],
#        [6.71277002e+07],
#        [7.36345653e+07],
#        [1.33260517e+08],
#        [5.44911825e+07],
#        [6.88514770e+07],
#        [4.58452306e+07],
#        [7.36345653e+07],
#        [4.21697160e+07],
#        [4.71852842e+07],
#        [1.11377882e+08],
#        [7.36345653e+07],
#        [8.95957462e+07],
#        [4.70863147e+07],
#        [5.53775184e+07],
#        [7.36345653e+07],
#        [6.19501721e+07],
#        [4.77177730e+07],
#        [8.18959996e+07],
#        [3.41160838e+07],
#        [9.59390792e+07],
#        [8.98515943e+07],
#        [4.70953115e+07],
#        [7.36345653e+07],
#        [1.87128304e+07],
#        [4.09285213e+07],
#        [1.58725552e+07],
#        [8.79840228e+07],
#        [6.16101104e+07],
#        [8.19598503e+07],
#        [8.70087048e+07],
#        [5.66867810e+07],
#        [5.09654393e+07],
#        [3.83875293e+07],
#        [7.83387821e+07],
#        [5.58668125e+07],
#        [5.09579357e+07],
#        [5.44413186e+07],
#        [3.09299102e+07],
#        [5.19599462e+07],
#        [6.62795614e+07],
#        [9.50130075e+07],
#        [4.94185862e+07],
#        [8.98515943e+07],
#        [4.21697160e+07],
#        [6.99590508e+07],
#        [6.05288035e+07],
#        [5.56913995e+07],
#        [5.74455714e+07],
#        [5.64235234e+07],
#        [4.50000000e+07]])

# %% [markdown]
# ### Evaluating the model

# %%
mean_absolute_error(test_target, predictions)
# Out:
# 14623253.219443275

# %%
r2_score(test_target, predictions)
# Out:
# 0.5333241702997167

# %%
test_df = pd.concat([test_features, pd.DataFrame(test_target)], axis = 1)

# %%
test_df['predicted_price'] = predictions

# %% [markdown]
# #### Trying the second model

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
k_model = KNeighborsRegressor()

# %%
k_model.fit(train_features, train_target)
# Out:
# KNeighborsRegressor()

# %%
k_predictions = model.predict(test_features)

# %%
k_predictions
# Out:
# array([[6.17170169e+07],
#        [6.62795614e+07],
#        [4.64943585e+07],
#        [5.63678032e+07],
#        [7.36345653e+07],
#        [8.98515943e+07],
#        [6.05288035e+07],
#        [4.58452306e+07],
#        [7.36345653e+07],
#        [8.10633746e+07],
#        [6.88514770e+07],
#        [5.44413186e+07],
#        [5.18941356e+07],
#        [7.36345653e+07],
#        [8.33145717e+07],
#        [4.72736265e+07],
#        [2.63494694e+07],
#        [1.15872064e+08],
#        [7.36345653e+07],
#        [1.11556056e+08],
#        [1.11556056e+08],
#        [7.34393417e+07],
#        [1.29322030e+08],
#        [4.56530989e+07],
#        [6.50384773e+07],
#        [5.08754665e+07],
#        [8.98515943e+07],
#        [5.44413186e+07],
#        [9.41676022e+07],
#        [5.44413186e+07],
#        [6.17994861e+07],
#        [4.39831439e+07],
#        [6.21217531e+07],
#        [8.57089113e+07],
#        [5.88567058e+07],
#        [6.51759624e+07],
#        [4.56288959e+07],
#        [5.44413186e+07],
#        [5.44413186e+07],
#        [6.13629628e+07],
#        [6.51759624e+07],
#        [6.50384773e+07],
#        [8.98515943e+07],
#        [5.44413186e+07],
#        [6.88514770e+07],
#        [4.21697160e+07],
#        [3.33572934e+07],
#        [7.36345653e+07],
#        [9.94367835e+07],
#        [5.04827742e+07],
#        [1.15872064e+08],
#        [8.98515943e+07],
#        [1.25006022e+08],
#        [6.52828690e+07],
#        [6.18625950e+07],
#        [2.76241521e+07],
#        [7.36345653e+07],
#        [1.80000000e+07],
#        [4.64943585e+07],
#        [4.34197969e+07],
#        [4.70863147e+07],
#        [3.75994666e+07],
#        [4.77177730e+07],
#        [6.50384773e+07],
#        [1.08788993e+08],
#        [3.84699985e+07],
#        [5.44413186e+07],
#        [4.30109756e+07],
#        [6.88514770e+07],
#        [3.84699985e+07],
#        [6.88514770e+07],
#        [5.07658040e+07],
#        [5.44413186e+07],
#        [9.83247253e+07],
#        [5.44413186e+07],
#        [8.23113027e+07],
#        [5.35549826e+07],
#        [5.20963577e+07],
#        [5.23084289e+07],
#        [4.77177730e+07],
#        [5.44413186e+07],
#        [4.34197969e+07],
#        [7.34932840e+07],
#        [5.44413186e+07],
#        [7.66202639e+07],
#        [8.12555063e+07],
#        [4.21697160e+07],
#        [6.52323857e+07],
#        [5.44413186e+07],
#        [5.44413186e+07],
#        [5.13932875e+07],
#        [7.36345653e+07],
#        [7.36345653e+07],
#        [5.07658040e+07],
#        [8.98515943e+07],
#        [5.09579357e+07],
#        [8.18959996e+07],
#        [1.80000000e+07],
#        [5.44413186e+07],
#        [4.56530989e+07],
#        [4.04172918e+07],
#        [5.07658040e+07],
#        [4.70863147e+07],
#        [7.10873823e+07],
#        [6.21217531e+07],
#        [6.71277002e+07],
#        [7.36345653e+07],
#        [1.33260517e+08],
#        [5.44911825e+07],
#        [6.88514770e+07],
#        [4.58452306e+07],
#        [7.36345653e+07],
#        [4.21697160e+07],
#        [4.71852842e+07],
#        [1.11377882e+08],
#        [7.36345653e+07],
#        [8.95957462e+07],
#        [4.70863147e+07],
#        [5.53775184e+07],
#        [7.36345653e+07],
#        [6.19501721e+07],
#        [4.77177730e+07],
#        [8.18959996e+07],
#        [3.41160838e+07],
#        [9.59390792e+07],
#        [8.98515943e+07],
#        [4.70953115e+07],
#        [7.36345653e+07],
#        [1.87128304e+07],
#        [4.09285213e+07],
#        [1.58725552e+07],
#        [8.79840228e+07],
#        [6.16101104e+07],
#        [8.19598503e+07],
#        [8.70087048e+07],
#        [5.66867810e+07],
#        [5.09654393e+07],
#        [3.83875293e+07],
#        [7.83387821e+07],
#        [5.58668125e+07],
#        [5.09579357e+07],
#        [5.44413186e+07],
#        [3.09299102e+07],
#        [5.19599462e+07],
#        [6.62795614e+07],
#        [9.50130075e+07],
#        [4.94185862e+07],
#        [8.98515943e+07],
#        [4.21697160e+07],
#        [6.99590508e+07],
#        [6.05288035e+07],
#        [5.56913995e+07],
#        [5.74455714e+07],
#        [5.64235234e+07],
#        [4.50000000e+07]])

# %%
r2_score(test_target, k_predictions)
# Out:
# 0.5333241702997167
